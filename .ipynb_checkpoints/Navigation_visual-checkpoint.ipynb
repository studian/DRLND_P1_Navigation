# %% [markdown]
# # Banana Navigation
#
# ---
# This is the first project of the [Deep Reinforcement Learning Nanodegree](https://www.udacity.com/course/deep-reinforcement-learning-nanodegree--nd893).
#
# ### 1. Start the Environment
#
# this code is implemented on Window 10.

# %%
from unityagents import UnityEnvironment
from dqn_agent import Agent
import numpy as np
import random
import torch
import pickle
from collections import deque
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
env = UnityEnvironment(file_name="unity/VisualBanana_Linux/Banana.x86")
# Out:
# INFO:unityagents:
# 'Academy' started successfully!
# Unity Academy name: Academy
#         Number of Brains: 1
#         Number of External Brains : 1
#         Lesson number : 0
#         Reset Parameters :
#
# Unity brain name: BananaBrain
#         Number of Visual Observations (per agent): 1
#         Vector Observation space type: continuous
#         Vector Observation space size (per agent): 0
#         Number of stacked Vector Observation: 1
#         Vector Action space type: discrete
#         Vector Action space size (per agent): 4
#         Vector Action descriptions: , , ,

# %%
# get the default brain
brain_name = env.brain_names[0]
brain = env.brains[brain_name]

# %% [markdown]
# ### 2. Examine the State and Action Spaces
#
# The simulation contains a single agent that navigates a large environment.  At each time step, it has four actions at its disposal:
# - `0` - walk forward
# - `1` - walk backward
# - `2` - turn left
# - `3` - turn right
#
# The state space has `37` dimensions and contains the agent's velocity, along with ray-based perception of objects around agent's forward direction.  A reward of `+1` is provided for collecting a yellow banana, and a reward of `-1` is provided for collecting a blue banana.

# %%
# reset the environment
env_info = env.reset(train_mode=True)[brain_name]

# number of agents in the environment
print('Number of agents:', len(env_info.agents))

# number of actions
action_size = brain.vector_action_space_size
print('Number of actions:', action_size)

# examine the state space 
state = env_info.visual_observations[0]
print('States look like:')
plt.imshow(np.squeeze(state))
plt.show()
state_size = state.shape
print('States have shape:', state.shape)
# Out:
# Number of agents: 1
# Number of actions: 4
# States look like:
# States have shape: (1, 84, 84, 3)

# %% [markdown]
# ### 3. define the DQN
#
# dqn execute DQN algorithm according to agent mode. you can choose one from `vanilla`, `double`, `prioritized`, `dueling`, `rainbow`.

# %%
def dqn(agent, n_episodes=2000, max_t=1000, eps_start=1.0, eps_end=0.01, eps_decay=0.995):
    """Deep Q-Learning.
    
    Params
    ======
        n_episodes (int): maximum number of training episodes
        max_t (int): maximum number of timesteps per episode
        eps_start (float): starting value of epsilon, for epsilon-greedy action selection
        eps_end (float): minimum value of epsilon
        eps_decay (float): multiplicative factor (per episode) for decreasing epsilon
    """
    scores = []                        # list containing scores from each episode
    scores_window = deque(maxlen=100)  # last 100 scores
    eps = eps_start                    # initialize epsilon
    for i_episode in range(1, n_episodes+1):
        env_info = env.reset(train_mode=True)[brain_name]  # reset the environment
        state = env_info.visual_observations[0]            # get the current state
        score = 0                                          # initialize the score
        for t in range(max_t):
            action = agent.act(state, eps).astype(int)     # select an action
            #np.int64 raise error AttributeError: 'numpy.int64' object has no attribute 'keys'
            env_info = env.step(action)[brain_name]        # send the action to the environment
            next_state = env_info.visual_observations[0]   # get the next state
            reward = env_info.rewards[0]                   # get the reward
            done = env_info.local_done[0]                  # see if episode has finished
            agent.step(state, action, reward, next_state, done)
            score += reward                                # update the score
            state = next_state                             # roll over the state to next time step
            if done:                                       # exit loop if episode finished
                break
        scores_window.append(score)       # save most recent score
        scores.append(score)              # save most recent score
        eps = max(eps_end, eps_decay*eps) # decrease epsilon
        print('\rEpisode {}\tAverage Score: {:.2f}'.format(i_episode, np.mean(scores_window)), end="")
        if i_episode % 100 == 0:
            print('\rEpisode {}\tAverage Score: {:.2f}'.format(i_episode, np.mean(scores_window)))
        if np.mean(scores_window)>=200.0:
            print('\nEnvironment solved in {:d} episodes!\tAverage Score: {:.2f}'.format(i_episode-100, np.mean(scores_window)))
            torch.save(agent.qnetwork_local.state_dict(), 'checkpoint.pth')
            break
    return scores

# %% [markdown]
# ### 4. train agent

# %%
agent = Agent(state_size=37, action_size=4, seed=0, mode="vanilla", visual=True)
double_scores = dqn(agent)

with open('saved_scores/vanilla_visual_scores.txt', 'wb') as f:
    pickle.dump(double_scores, f)
# Out:
# Episode 14	Average Score: 0.07

# %%
agent = Agent(state_size=37, action_size=4, seed=0, mode="double", visual=True)
double_scores = dqn(agent)

with open('saved_scores/double_visual_scores.txt', 'wb') as f:
    pickle.dump(double_scores, f)
# Out:
# Episode 100	Average Score: 0.92
# Episode 200	Average Score: 3.29
# Episode 300	Average Score: 6.95
# Episode 400	Average Score: 10.40
# Episode 500	Average Score: 13.27
# Episode 600	Average Score: 14.09
# Episode 700	Average Score: 14.61
# Episode 800	Average Score: 15.09
# Episode 900	Average Score: 15.44
# Episode 1000	Average Score: 16.19
# Episode 1100	Average Score: 16.82
# Episode 1200	Average Score: 16.61
# Episode 1300	Average Score: 16.20
# Episode 1400	Average Score: 17.33
# Episode 1500	Average Score: 16.08
# Episode 1600	Average Score: 16.82
# Episode 1700	Average Score: 16.94
# Episode 1800	Average Score: 16.81
# Episode 1900	Average Score: 16.39
# Episode 2000	Average Score: 16.95

# %%
agent = Agent(state_size=37, action_size=4, seed=0, mode="prioritized", visual=True)
prioritized_scores, prioritized_scores_window = dqn(agent)

with open('saved_scores/prioritized_visual_scores.txt', 'wb') as f:
    pickle.dump(prioritized_scores, f)
# Out:
# Episode 100	Average Score: 0.46
# Episode 200	Average Score: 2.26
# Episode 300	Average Score: 4.23
# Episode 400	Average Score: 5.59
# Episode 500	Average Score: 6.85
# Episode 600	Average Score: 7.99
# Episode 700	Average Score: 8.89
# Episode 800	Average Score: 8.93
# Episode 900	Average Score: 9.76
# Episode 1000	Average Score: 9.67
# Episode 1100	Average Score: 9.82
# Episode 1200	Average Score: 9.701
# Episode 1300	Average Score: 9.903
# Episode 1400	Average Score: 7.25
# Episode 1500	Average Score: 8.81
# Episode 1600	Average Score: 8.17
# Episode 1700	Average Score: 8.59
# Episode 1800	Average Score: 8.43
# Episode 1900	Average Score: 7.84
# Episode 2000	Average Score: 9.15

# %%
agent = Agent(state_size=37, action_size=4, seed=0, mode="dueling")
dueling_scores, dueling_scores_window = dqn(agent)

with open('saved_scores/dueling_scores.txt', 'wb') as f:
    pickle.dump(dueling_scores, f)
# Out:
# Episode 100	Average Score: 0.46
# Episode 200	Average Score: 3.16
# Episode 300	Average Score: 6.74
# Episode 400	Average Score: 9.96
# Episode 500	Average Score: 13.33
# Episode 600	Average Score: 14.06
# Episode 700	Average Score: 13.93
# Episode 800	Average Score: 14.30
# Episode 900	Average Score: 14.88
# Episode 1000	Average Score: 15.46
# Episode 1100	Average Score: 15.56
# Episode 1200	Average Score: 14.64
# Episode 1300	Average Score: 15.80
# Episode 1400	Average Score: 15.86
# Episode 1500	Average Score: 14.74
# Episode 1600	Average Score: 14.89
# Episode 1700	Average Score: 14.32
# Episode 1800	Average Score: 14.27
# Episode 1900	Average Score: 14.85
# Episode 2000	Average Score: 14.70

# %%
agent = Agent(state_size=37, action_size=4, seed=0, mode="rainbow")
rainbow_scores, rainbow_scores_window = dqn(agent)

with open('saved_scores/rainbow_scores.txt', 'wb') as f:
    pickle.dump(rainbow_scores, f)
# Out:
# Episode 100	Average Score: 1.02
# Episode 200	Average Score: 2.66
# Episode 300	Average Score: 6.61
# Episode 400	Average Score: 9.93
# Episode 500	Average Score: 12.39
# Episode 600	Average Score: 11.57
# Episode 700	Average Score: 13.17
# Episode 800	Average Score: 13.44
# Episode 900	Average Score: 13.45
# Episode 1000	Average Score: 13.41
# Episode 1100	Average Score: 13.34
# Episode 1200	Average Score: 12.87
# Episode 1300	Average Score: 12.49
# Episode 1400	Average Score: 13.44
# Episode 1500	Average Score: 12.66
# Episode 1600	Average Score: 13.29
# Episode 1700	Average Score: 13.64
# Episode 1800	Average Score: 13.77
# Episode 1900	Average Score: 13.43
# Episode 2000	Average Score: 13.94

# %%
agent.save()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-7ec4586f5fb2> in <module>()
# ----> 1 agent.save()
#
# AttributeError: 'Agent' object has no attribute 'save'

# %% [markdown]
# ### 5. close the environment.

# %%
env.close()

# %% [markdown]
# ### 6. Comparison

# %%
vanilla, = plt.plot(vanilla_scores, label='vanilla')
double, = plt.plot(double_scores, label='double')
prioritized, = plt.plot(prioritized_scores, label='prioritized')
dueling, = plt.plot(dueling_scores, label='dueling')
rainbow, = plt.plot(rainbow_scores, label='rainbow')
plt.legend(handles=[vanilla, double, prioritized, dueling, rainbow])
plt.show()

# %%
def rolling_mean(scores):
    rolling_mean = []
    scores_window = deque(maxlen=100)
    for i in range(len(scores)):
        scores_window.append(scores[i])
        rolling_mean.append(np.mean(scores_window))
    return rolling_mean
vanila_rolling_mean = rolling_mean(vanilla_scores)
double_rolling_mean = rolling_mean(double_scores)
prioritized_rolling_mean = rolling_mean(prioritized_scores)
dueling_rolling_mean = rolling_mean(dueling_scores)
rainbow_rolling_mean = rolling_mean(rainbow_scores)

# %%
vanilla, = plt.plot(vanila_rolling_mean, label='vanilla')
double, = plt.plot(double_rolling_mean, label='double')
prioritized, = plt.plot(prioritized_rolling_mean, label='prioritized')
dueling, = plt.plot(dueling_rolling_mean, label='dueling')
rainbow, = plt.plot(rainbow_rolling_mean, label='rainbow')
plt.legend(handles=[vanilla, double, prioritized, dueling, rainbow])
plt.show()
